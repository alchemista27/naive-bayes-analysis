# %%
# Import library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re


# Load data
dt = pd.read_csv('turbo-vpn-reviews.csv')
dt
# Out:
#             userName                                            content  \
# 0     Raudatus Syifa  sangat berguna buat masuk ke situs yang susah ...
# 1          Kadek Eka  apk sampah jaringannya lemot terus iklan diman...
# 2    Wira Zizo Gladi  kenapa dia gak hilang dari status bar ya?? man...
# 3       Jaja Subagja  bintang5pasti dong selama saya menggunakan vpn...
# 4           TIm Balu  masalah nya suka putus2 sendiri vpn nya..!!20 ...
# ..               ...                                                ...
# 495    Feri Hermawan                    lancar jaya sedikit iklan wajar
# 496      Irmank Manl  aplikasi nya sangat bermanfaat dan bagus saat ...
# 497      Nurul Laili                            bagus tp iklannya bnyak
# 498        pak Katim             bagus nih jaringan nya tiada nge. like
# 499      Oni Parlina        mudah dipakai dan sangat membantu sekali...
#
#      score                   at
# 0        5  2024-03-20 16:39:28
# 1        1  2024-03-17 20:26:21
# 2        1  2024-02-24 18:21:40
# 3        5  2024-03-20 01:37:41
# 4        1  2024-03-04 06:43:44
# ..     ...                  ...
# 495      5  2024-02-08 08:21:48
# 496      5  2024-03-18 14:11:40
# 497      4  2024-03-16 13:44:31
# 498      5  2024-02-29 13:51:38
# 499      5  2024-03-19 20:04:46
#
# [500 rows x 4 columns]

# %%
# Checking missing value
dt['content'].isna().sum()


# Checking any duplicated content
dt['content'].duplicated().sum()

# Select data content and score only
data = dt[['content', 'score']]
data

# Preprocesing the text
def preprocress(text):
    text = re.sub('<[^>]*>', '', text)
    emoticons = re.findall('(?::|;|=)()(?:-)?(?:\)|\(|D|P)',
                           text)
    text = (re.sub('[\W]+', ' ', text.lower()) +
            ' '.join(emoticons).replace('-', ''))
    return text

data['content'] = data['content'].apply(lambda x: preprocress(x))
data

# Labeling
def labeling(score):
    if score < 3:
        return 'Negatif'
    elif score == 4:
        return 'Positif'
    elif score == 5:
        return 'Positif'

data['label'] = data['score'].apply(lambda x: labeling(x))
data

# checking missing value
data.isna().sum()

# Dropping missing value
data = data.dropna(axis=0)
data.isna().sum()
# Out:
# /tmp/ipykernel_5932/1230605101.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['content'] = data['content'].apply(lambda x: preprocress(x))
# /tmp/ipykernel_5932/1230605101.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label'] = data['score'].apply(lambda x: labeling(x))
# content    0
# score      0
# label      0
# dtype: int64

# %%
# Content has been in lowwer case
# Stopword Removal
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/septian/anaconda3/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: click in /home/septian/anaconda3/lib/python3.11/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/septian/anaconda3/lib/python3.11/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/septian/anaconda3/lib/python3.11/site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in /home/septian/anaconda3/lib/python3.11/site-packages (from nltk) (4.65.0)

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = stopwords.words('indonesian')
data['content_sw'] = data['content'].apply(lambda x:' '.join([word for word in x.split() if word not in (stop)]))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/septian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data
# Out:
#                                                content  score    label  \
# 0    sangat berguna buat masuk ke situs yang susah ...      5  Positif
# 1    apk sampah jaringannya lemot terus iklan diman...      1  Negatif
# 2    kenapa dia gak hilang dari status bar ya mana ...      1  Negatif
# 3    bintang5pasti dong selama saya menggunakan vpn...      5  Positif
# 4    masalah nya suka putus2 sendiri vpn nya 20 men...      1  Negatif
# ..                                                 ...    ...      ...
# 495                    lancar jaya sedikit iklan wajar      5  Positif
# 496  aplikasi nya sangat bermanfaat dan bagus saat ...      5  Positif
# 497                            bagus tp iklannya bnyak      4  Positif
# 498              bagus nih jaringan nya tiada nge like      5  Positif
# 499          mudah dipakai dan sangat membantu sekali       5  Positif
#
#                                             content_sw
# 0    berguna masuk situs susah akses suka error ikl...
# 1    apk sampah jaringannya lemot iklan dimana iya ...
# 2    gak hilang status bar ya tulisannya gak enak k...
# 3    bintang5pasti vpn turbo memuaskan recommended ...
# 4    nya suka putus2 vpn nya 20 menit jalan bagus t...
# ..                                                 ...
# 495                            lancar jaya iklan wajar
# 496  aplikasi nya bermanfaat bagus bermain game apl...
# 497                            bagus tp iklannya bnyak
# 498              bagus nih jaringan nya tiada nge like
# 499                             mudah dipakai membantu
#
# [477 rows x 4 columns]

# %%
# Tokenize
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
data['content_token'] = data['content_sw'].apply(lambda x: word_tokenize(x))
data
# Out:
# [nltk_data] Downloading package punkt to /home/septian/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                content  score    label  \
# 0    sangat berguna buat masuk ke situs yang susah ...      5  Positif
# 1    apk sampah jaringannya lemot terus iklan diman...      1  Negatif
# 2    kenapa dia gak hilang dari status bar ya mana ...      1  Negatif
# 3    bintang5pasti dong selama saya menggunakan vpn...      5  Positif
# 4    masalah nya suka putus2 sendiri vpn nya 20 men...      1  Negatif
# ..                                                 ...    ...      ...
# 495                    lancar jaya sedikit iklan wajar      5  Positif
# 496  aplikasi nya sangat bermanfaat dan bagus saat ...      5  Positif
# 497                            bagus tp iklannya bnyak      4  Positif
# 498              bagus nih jaringan nya tiada nge like      5  Positif
# 499          mudah dipakai dan sangat membantu sekali       5  Positif
#
#                                             content_sw  \
# 0    berguna masuk situs susah akses suka error ikl...
# 1    apk sampah jaringannya lemot iklan dimana iya ...
# 2    gak hilang status bar ya tulisannya gak enak k...
# 3    bintang5pasti vpn turbo memuaskan recommended ...
# 4    nya suka putus2 vpn nya 20 menit jalan bagus t...
# ..                                                 ...
# 495                            lancar jaya iklan wajar
# 496  aplikasi nya bermanfaat bagus bermain game apl...
# 497                            bagus tp iklannya bnyak
# 498              bagus nih jaringan nya tiada nge like
# 499                             mudah dipakai membantu
#
#                                          content_token
# 0    [berguna, masuk, situs, susah, akses, suka, er...
# 1    [apk, sampah, jaringannya, lemot, iklan, diman...
# 2    [gak, hilang, status, bar, ya, tulisannya, gak...
# 3    [bintang5pasti, vpn, turbo, memuaskan, recomme...
# 4    [nya, suka, putus2, vpn, nya, 20, menit, jalan...
# ..                                                 ...
# 495                       [lancar, jaya, iklan, wajar]
# 496  [aplikasi, nya, bermanfaat, bagus, bermain, ga...
# 497                       [bagus, tp, iklannya, bnyak]
# 498      [bagus, nih, jaringan, nya, tiada, nge, like]
# 499                         [mudah, dipakai, membantu]
#
# [477 rows x 5 columns]

# %%
# Stemming
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()


# Create function for stemming
def stemmed_wrapper(text):
    return stemmer.stem(text)

text_dict = {}
count = 0

for row in data['content_token']:
    for text in row:
        if text not in text_dict:
            text_dict[text] = ' '

print(len(text_dict))

for word in text_dict:
    text_dict[word] = stemmed_wrapper(word)
    count+=1
    print(count,':',word,':',text_dict[word])

print(text_dict)

# Adding stemmed text into the dataframe
def get_stemmed_text(text):
    return [text_dict[word] for word in text]

data['content_stem'] = data['content_token'].apply(lambda x:' '.join(get_stemmed_text(x)))
data
# Out:
# 1450
# 1 : berguna : guna
# 2 : masuk : masuk
# 3 : situs : situs
# 4 : susah : susah
# 5 : akses : akses
# 6 : suka : suka
# 7 : error : error
# 8 : iklan : iklan
# 9 : nya : nya
# 10 : gak : gak
# 11 : banget : banget
# 12 : kali : kali
# 13 : main : main
# 14 : cuman : cuman
# 15 : 2 : 2
# 16 : 3 : 3
# 17 : muncul : muncul
# 18 : durasi : durasi
# 19 : iklannya : iklan
# 20 : kerasa : rasa
# 21 : wajar : wajar
# 22 : intinya : inti
# 23 : tuh : tuh
# 24 : aplikasi : aplikasi
# 25 : bagus : bagus
# 26 : o : o
# 27 : ω :
# 28 : apk : apk
# 29 : sampah : sampah
# 30 : jaringannya : jaring
# 31 : lemot : lot
# 32 : dimana : mana
# 33 : iya : iya
# 34 : dimaklumi : maklum
# 35 : yoo : yoo
# 36 : astaghh : astaghh
# 37 : nonton : nonton
# 38 : live : live
# 39 : streaming : streaming
# 40 : aja : aja
# 41 : kualitas : kualitas
# 42 : mentok : mentok
# 43 : 240p : 240p
# 44 : itupun : itu
# 45 : kebanyakan : banyak
# 46 : mutar : mutar
# 47 : 144p : 144p
# 48 : loading : loading
# 49 : dibandingkan : banding
# 50 : vpn : vpn
# 51 : yg : yg
# 52 : wow : wow
# 53 : pake : pake
# 54 : tembus : tembus
# 55 : 1080p : 1080p
# 56 : lancar : lancar
# 57 : jaringan : jaring
# 58 : nyesel : nyesel
# 59 : download : download
# 60 : rekomendasi : rekomendasi
# 61 : hilang : hilang
# 62 : status : status
# 63 : bar : bar
# 64 : ya : ya
# 65 : tulisannya : tulis
# 66 : enak : enak
# 67 : kesalahan : salah
# 68 : perangkat : perangkat
# 69 : ketuk : ketuk
# 70 : menyambung : sambung
# 71 : disuruh : suruh
# 72 : nyambung : nyambung
# 73 : matikan : mati
# 74 : lihat : lihat
# 75 : suruh : suruh
# 76 : rajin : rajin
# 77 : keuntungan : untung
# 78 : pembikinnya : bikin
# 79 : bintang5pasti : bintang5pasti
# 80 : turbo : turbo
# 81 : memuaskan : muas
# 82 : recommended : recommended
# 83 : kalian2 : kalian2
# 84 : butuh : butuh
# 85 : best : best
# 86 : skrg : skrg
# 87 : msh : msh
# 88 : terbaik : baik
# 89 : mudah : mudah
# 90 : ga : ga
# 91 : sulit : sulit
# 92 : jaga : jaga
# 93 : tingkatkan : tingkat
# 94 : pengalaman : alam
# 95 : skrng : skrng
# 96 : coba : coba
# 97 : buktikan : bukti
# 98 : bedakan : beda
# 99 : dngn : dngn
# 100 : putus2 : putus2
# 101 : 20 : 20
# 102 : menit : menit
# 103 : jalan : jalan
# 104 : tiba2 : tiba2
# 105 : ganti : ganti
# 106 : lokasi : lokasi
# 107 : perbaiki : baik
# 108 : kasih : kasih
# 109 : 1 : 1
# 110 : bintang : bintang
# 111 : 5 : 5
# 112 : maff : maff
# 113 : buang : buang
# 114 : delete : delete
# 115 : karna : karna
# 116 : sanga : sanga
# 117 : kesal : kesal
# 118 : koneksi : koneksi
# 119 : non : non
# 120 : aktif : aktif
# 121 : kayak : kayak
# 122 : gini : gin
# 123 : sih : sih
# 124 : tpi : tpi
# 125 : msi : msi
# 126 : agret : agret
# 127 : sya : sya
# 128 : brikn : brikn
# 129 : 4 : 4
# 130 : bntng : bntng
# 131 : dlu : dlu
# 132 : lgi : lgi
# 133 : diperbaiki : baik
# 134 : sprti : sprti
# 135 : terputus : putus
# 136 : msih : msih
# 137 : lambat : lambat
# 138 : trllu : trllu
# 139 : membantu : bantu
# 140 : membuka : buka
# 141 : link : link
# 142 : d : d
# 143 : blok : blok
# 144 : sukses : sukses
# 145 : gbsa : gbsa
# 146 : kurangin : rangin
# 147 : nnti : nnti
# 148 : klo : klo
# 149 : bsa : bsa
# 150 : lg : lg
# 151 : tmbh : tmbh
# 152 : bntangnya : bntangnya
# 153 : trims : trims
# 154 : cocok : cocok
# 155 : game : game
# 156 : tolong : tolong
# 157 : kadang : kadang
# 158 : putus : putus
# 159 : sendri : sendri
# 160 : mohon : mohon
# 161 : terimakasih : terimakasih
# 162 : berkomentar : komentar
# 163 : mts : mts
# 164 : 2015 : 2015
# 165 : an : an
# 166 : pakai : pakai
# 167 : bagiku : bagi
# 168 : keren : keren
# 169 : pengin : pengin
# 170 : luas : luas
# 171 : premium : premium
# 172 : berlangganan : langgan
# 173 : memilih : pilih
# 174 : uji : uji
# 175 : pokoknya : pokok
# 176 : makasih : makasih
# 177 : cepat : cepat
# 178 : ribet : ribet
# 179 : namanya : nama
# 180 : gratis : gratis
# 181 : bayar : bayar
# 182 : aplikasinya : aplikasi
# 183 : boss : boss
# 184 : menyenangkan : senang
# 185 : web : web
# 186 : jangkau : jangkau
# 187 : memakai : pakai
# 188 : kuharap : harap
# 189 : perkembangan : kembang
# 190 : update : update
# 191 : memudahkan : mudah
# 192 : semangat : semangat
# 193 : kawan : kawan
# 194 : kerja : kerja
# 195 : asa : asa
# 196 : hati : hati
# 197 : disebabkan : sebab
# 198 : mulut : mulut
# 199 : tdak : tdak
# 200 : dngar : dngar
# 201 : orng² : orng
# 202 : kenal : kenal
# 203 : dri : dri
# 204 : lingkungan : lingkung
# 205 : nilai : nilai
# 206 : mna : mna
# 207 : mulutnya : mulut
# 208 : otomatis : otomatis
# 209 : pilih : pilih
# 210 : peramban : ramban
# 211 : full : full
# 212 : maksimal : maksimal
# 213 : jam : jam
# 214 : segi : segi
# 215 : lancarnya : lancar
# 216 : kenceng : kenceng
# 217 : bikin : bikin
# 218 : eror : eror
# 219 : kalo : kalo
# 220 : kedepannya : depan
# 221 : saldo : saldo
# 222 : dana : dana
# 223 : kepotong : potong
# 224 : no : no
# 225 : minalnya : mal
# 226 : mengembalikan : kembali
# 227 : sah : sah
# 228 : dikurangi : rang
# 229 : meganggu : meganggu
# 230 : ditingkatkan : tingkat
# 231 : semoga : moga
# 232 : ditambah : tambah
# 233 : dg : dg
# 234 : fitur : fitur
# 235 : terjemahan : terjemah
# 236 : sesuai : sesuai
# 237 : negara : negara
# 238 : pengguna : guna
# 239 : pengupload : pengupload
# 240 : video : video
# 241 : bokep : bokep
# 242 : barat : barat
# 243 : subtitle : subtitle
# 244 : diterjemahkan : terjemah
# 245 : donk : donk
# 246 : browsing : browsing
# 247 : terjaga : jaga
# 248 : website : website
# 249 : kunjungi : kunjung
# 250 : amin : amin
# 251 : lite : lite
# 252 : teliti : teliti
# 253 : baca : baca
# 254 : mengumpulkan : kumpul
# 255 : data : data
# 256 : memberikannya : beri
# 257 : ketiga : tiga
# 258 : teman : teman
# 259 : bijak : bijak
# 260 : langsung : langsung
# 261 : menggunaka : menggunaka
# 262 : kesini : kesini
# 263 : dikoreksi : koreksi
# 264 : penempatan : tempat
# 265 : memunculkan : muncul
# 266 : tsb : tsb
# 267 : lumayan : lumayan
# 268 : lelet : lelet
# 269 : optimalkan : optimal
# 270 : berat : berat
# 271 : browser : browser
# 272 : mengunjungi : unjung
# 273 : kesukaan : suka
# 274 : x : x
# 275 : twitter : twitter
# 276 : donwload : donwload
# 277 : motivasi : motivasi
# 278 : pagi : pagi
# 279 : p : p
# 280 : pembelajaran : ajar
# 281 : biologi : biologi
# 282 : direkomendasi : rekomendasi
# 283 : buka : buka
# 284 : isi : isi
# 285 : dgn : dgn
# 286 : kecewa : kecewa
# 287 : upload : upload
# 288 : file : file
# 289 : terbatas : batas
# 290 : sistem : sistem
# 291 : websitenya : websitenya
# 292 : sayangnya : sayang
# 293 : dikenakan : kena
# 294 : biaya : biaya
# 295 : saran : saran
# 296 : bebas : bebas
# 297 : sebulan : bulan
# 298 : keberatan : berat
# 299 : fnxedws : fnxedws
# 300 : berjalan : jalan
# 301 : secepat : cepat
# 302 : siput : siput
# 303 : app : app
# 304 : google : google
# 305 : stress : stress
# 306 : benarkan : benar
# 307 : plz : plz
# 308 : internet : internet
# 309 : two : two
# 310 : thumbs : thumbs
# 311 : up : up
# 312 : for : for
# 313 : parah : parah
# 314 : koneksin : koneksin
# 315 : sebentar : sebentar
# 316 : kuawalahan : kuawalahan
# 317 : bulak : bulak
# 318 : appk : appk
# 319 : nyaman : nyaman
# 320 : terkadang : terkadang
# 321 : makai : maka
# 322 : anti : anti
# 323 : lemotmantap : lemotmantap
# 324 : donlot : donlot
# 325 : jamin : jamin
# 326 : mantap : mantap
# 327 : tinggal : tinggal
# 328 : ketik : ketik
# 329 : mantapppp : mantapppp
# 330 : okeh : okeh
# 331 : trimakasih : trimakasih
# 332 : stock : stock
# 333 : atur : atur
# 334 : membutuhkan : butuh
# 335 : mencakup : cakup
# 336 : berhubungan : hubung
# 337 : jenis : jenis
# 338 : mode : mode
# 339 : kendala : kendala
# 340 : palagi : palagi
# 341 : paid : paid
# 342 : kaum : kaum
# 343 : pemersatu : satu
# 344 : bangsa : bangsa
# 345 : simpel : simpel
# 346 : klik : klik
# 347 : server : server
# 348 : dimatikan : mati
# 349 : have : have
# 350 : a : a
# 351 : nice : nice
# 352 : private : private
# 353 : time : time
# 354 : mengganggu : ganggu
# 355 : berbayar : bayar
# 356 : gratisan : gratis
# 357 : bayarannya : bayar
# 358 : wkwkwk : wkwkwk
# 359 : sumpah : sumpah
# 360 : ni : ni
# 361 : nyalain : nyalain
# 362 : matiin : matiin
# 363 : mulu : mulu
# 364 : iklanya : iklanya
# 365 : bgt : bgt
# 366 : alhamdulillah : alhamdulillah
# 367 : udah : udah
# 368 : make : make
# 369 : terbuka : buka
# 370 : fungsinya : fungsi
# 371 : sia : sia
# 372 : pendukung : dukung
# 373 : bagusssss : bagusssss
# 374 : lahhh : lahhh
# 375 : merusak : rusak
# 376 : memperlambat : lambat
# 377 : sinyal : sinyal
# 378 : detik : detik
# 379 : nyala : nyala
# 380 : jd : jd
# 381 : slot : slot
# 382 : rungkad : rungkad
# 383 : mengakses : akses
# 384 : kurangi : kurang
# 385 : super : super
# 386 : pokoya : pokoya
# 387 : puas : puas
# 388 : mudah2han : mudah2han
# 389 : haya : haya
# 390 : bicara : bicara
# 391 : mantaaab : mantaaab
# 392 : awalannya : awal
# 393 : kencang : kencang
# 394 : selang : selang
# 395 : mendadak : dadak
# 396 : setabil : setabil
# 397 : koreksi : koreksi
# 398 : pengaruh : pengaruh
# 399 : peningkatan : tingkat
# 400 : maaf : maaf
# 401 : kaya : kaya
# 402 : secem : secem
# 403 : blokiran : blokir
# 404 : ok : ok
# 405 : bgus : bgus
# 406 : utk : utk
# 407 : penguat : kuat
# 408 : daya : daya
# 409 : jelajah : jelajah
# 410 : ditembus : tembus
# 411 : ganggu : ganggu
# 412 : good : good
# 413 : application : application
# 414 : favorit : favorit
# 415 : aman : aman
# 416 : top : top
# 417 : gan : gan
# 418 : log : log
# 419 : in : in
# 420 : roblox : roblox
# 421 : disconnected : disconnected
# 422 : terlaku : laku
# 423 : membosan : bos
# 424 : kn : kn
# 425 : krn : krn
# 426 : sy : sy
# 427 : sayang : sayang
# 428 : teralihkan : alih
# 429 : mengubah : ubah
# 430 : thanks : thanks
# 431 : kecepatan : cepat
# 432 : akurasi : akurasi
# 433 : kenyamanan : nyaman
# 434 : dpt : dpt
# 435 : lbh : lbh
# 436 : menikmati : nikmat
# 437 : situs2 : situs2
# 438 : oh : oh
# 439 : pencarian : cari
# 440 : finally : finally
# 441 : terblokir : blokir
# 442 : tank : tank
# 443 : too : too
# 444 : rugi : rugi
# 445 : dowload : dowload
# 446 : lemah : lemah
# 447 : tlng : tlng
# 448 : benerin : benerin
# 449 : efisien : efisien
# 450 : pekara : kara
# 451 : selebih : lebih
# 452 : oke : oke
# 453 : internetan : internetan
# 454 : transit : transit
# 455 : bandara : bandara
# 456 : china : china
# 457 : internetnya : internetnya
# 458 : q : q
# 459 : aktifkan : aktif
# 460 : chat : chat
# 461 : ngk : ngk
# 462 : lag : lag
# 463 : bermain : main
# 464 : dipilih : pilih
# 465 : motong : motong
# 466 : 187 : 187
# 467 : 500 : 500
# 468 : uang : uang
# 469 : sungguh : sungguh
# 470 : merugikan : rugi
# 471 : terima : terima
# 472 : terpotong : potong
# 473 : konfirmasi : konfirmasi
# 474 : sang : sang
# 475 : at : at
# 476 : membatu : batu
# 477 : ikalanya : ikalanya
# 478 : kondisi : kondisi
# 479 : jos : jos
# 480 : kukira : kira
# 481 : memperburuk : buruk
# 482 : berkurang : kurang
# 483 : biar : biar
# 484 : jelek : jelek
# 485 : free : free
# 486 : dah : dah
# 487 : memaksa : paksa
# 488 : perlancar : lancar
# 489 : gampang : gampang
# 490 : ngeluarin : ngeluarin
# 491 : nyari : nyari
# 492 : kasi : kasi
# 493 : gamenya : gamenya
# 494 : peminatnya : minat
# 495 : cari : cari
# 496 : turbu : turbu
# 497 : adlah : adlah
# 498 : teman2 : teman2
# 499 : jgn : jgn
# 500 : pusing : pusing
# 501 : lengkap : lengkap
# 502 : pastinya : pasti
# 503 : blokkkkkk : blokkkkkk
# 504 : the : the
# 505 : smua : smua
# 506 : pemecah : pecah
# 507 : cakep : cakep
# 508 : dlm : dlm
# 509 : berselancar : selancar
# 510 : dunia : dunia
# 511 : fine2 : fine2
# 512 : aj : aj
# 513 : sq : sq
# 514 : enjoy : enjoy
# 515 : mnggunkn : mnggunkn
# 516 : apliksi : apliksi
# 517 : skitar : skitar
# 518 : stlh : stlh
# 519 : gk : gk
# 520 : tau : tau
# 521 : ap : ap
# 522 : pnybbnya : pnybbnya
# 523 : aplikasiny : aplikasiny
# 524 : kecepatannya : cepat
# 525 : ip : ip
# 526 : hp : hp
# 527 : disembunyikan : sembunyi
# 528 : kedeteksi : deteksi
# 529 : pegunungan : gunung
# 530 : pelayanan : layan
# 531 : maaantaaap : maaantaaap
# 532 : hebat : hebat
# 533 : perjalanan : jalan
# 534 : pribadi : pribadi
# 535 : perbaikan : baik
# 536 : buruk : buruk
# 537 : stabil : stabil
# 538 : terparah : parah
# 539 : speed : speed
# 540 : 15 : 15
# 541 : bytes : bytes
# 542 : memperbaiki : baik
# 543 : la : la
# 544 : yutube : yutube
# 545 : dilatar : latar
# 546 : gantiin : gantiin
# 547 : yutub : yutub
# 548 : pas : pas
# 549 : denger : denger
# 550 : musik : musik
# 551 : vpnnya : vpnnya
# 552 : usahakan : usaha
# 553 : cuaca : cuaca
# 554 : apapun : apa
# 555 : yaa : yaa
# 556 : menyukai : suka
# 557 : negeri : negeri
# 558 : positivnya : positivnya
# 559 : ambil : ambil
# 560 : babi : babi
# 561 : ngrusak : ngrusak
# 562 : stop : stop
# 563 : un : un
# 564 : instal : instal
# 565 : cuuy : cuuy
# 566 : lecet : lecet
# 567 : dikontrol : kontrol
# 568 : gilaa : gilaa
# 569 : ngelag : ngelag
# 570 : dehh : dehh
# 571 : menghilangkan : hilang
# 572 : stres : stres
# 573 : pembuat : buat
# 574 : nobo : nobo
# 575 : bola : bola
# 576 : vvn : vvn
# 577 : nyrobot : nyrobot
# 578 : selebihnya : lebih
# 579 : mantaapp : mantaapp
# 580 : depannya : depan
# 581 : si : si
# 582 : bnyak : bnyak
# 583 : mati : mati
# 584 : optimal : optimal
# 585 : stabilan : stabil
# 586 : emang : emang
# 587 : sngat : sngat
# 588 : mengunduh : unduh
# 589 : ucapkan : ucap
# 590 : terimaksih : terimaksih
# 591 : lncar : lncar
# 592 : hrus : hrus
# 593 : dgan : dgan
# 594 : vip : vip
# 595 : banged : banged
# 596 : bertahan : tahan
# 597 : abis : abis
# 598 : off : off
# 599 : gimana : gimana
# 600 : uda : uda
# 601 : beli : beli
# 602 : mahal² : mahal
# 603 : film : film
# 604 : drama : drama
# 605 : kebuka : buka
# 606 : pakek : pakek
# 607 : apl : apl
# 608 : bos : bos
# 609 : senggol : senggol
# 610 : jempolan : jempol
# 611 : adam : adam
# 612 : gairah : gairah
# 613 : sex : sex
# 614 : bida : bida
# 615 : napikan : napikan
# 616 : orang : orang
# 617 : panatik : panatik
# 618 : mrngabaikan : mrngabaikan
# 619 : buatlah : buat
# 620 : konten : konten
# 621 : menarik : tarik
# 622 : sem : sem
# 623 : batasan : batas
# 624 : umur : umur
# 625 : ditetapkan : tetap
# 626 : menimbulkan : timbul
# 627 : masaalah : masaalah
# 628 : lumayanlah : lumayan
# 629 : gua : gua
# 630 : vidio : vidio
# 631 : klu : klu
# 632 : bangan : bangan
# 633 : ma : ma
# 634 : apc : apc
# 635 : walupun : walupun
# 636 : ado : ado
# 637 : sedik : dik
# 638 : gangaun : gangaun
# 639 : iklanyo : iklanyo
# 640 : klw : klw
# 641 : ajah : ajah
# 642 : tanksmantap : tanksmantap
# 643 : blokir : blokir
# 644 : terganggu : ganggu
# 645 : topmarkotop : topmarkotop
# 646 : pengmbang : pengmbang
# 647 : wajarlah : wajar
# 648 : penggunaanya : penggunaanya
# 649 : bantu : bantu
# 650 : penggunaan : guna
# 651 : uninstall : uninstall
# 652 : hapus : hapus
# 653 : ngerti : ngerti
# 654 : opsi : opsi
# 655 : menuhin : menuhin
# 656 : penyimpanan : simpan
# 657 : aq : aq
# 658 : dikurangin : rangin
# 659 : kaga : kaga
# 660 : tida : tida
# 661 : pencet : pencet
# 662 : ribu : ribu
# 663 : dikembalikan : kembali
# 664 : prosesnya : proses
# 665 : mai : mai
# 666 : truss : truss
# 667 : ulasan : ulas
# 668 : kerabat : kerabat
# 669 : mencoba : coba
# 670 : mengesan : es
# 671 : tertarik : tarik
# 672 : mencobanya : coba
# 673 : smoga : smoga
# 674 : mengecewakan : kecewa
# 675 : versi : versi
# 676 : selancar : selancar
# 677 : pro : pro
# 678 : conek : conek
# 679 : batas : batas
# 680 : apknya : apknya
# 681 : jni : jni
# 682 : mantul : mantul
# 683 : udh : udh
# 684 : sdh : sdh
# 685 : gthu : gthu
# 686 : kl : kl
# 687 : 6 : 6
# 688 : jg : jg
# 689 : gw : gw
# 690 : bntg : bntg
# 691 : mencari : cari
# 692 : fire : fire
# 693 : muda : muda
# 694 : menonton : tonton
# 695 : filem : filem
# 696 : yuuhuyyyy : yuuhuyyyy
# 697 : hemat : hemat
# 698 : bet : bet
# 699 : mobile : mobile
# 700 : legends : legends
# 701 : mending : mending
# 702 : kelancaran : lancar
# 703 : wi : wi
# 704 : fi : fi
# 705 : pelanggan : langgan
# 706 : tetep : tetep
# 707 : keganggu : ganggu
# 708 : maen : maen
# 709 : perluas : luas
# 710 : murah : murah
# 711 : alhamdulilah : alhamdulilah
# 712 : video² : video
# 713 : seneng : neng
# 714 : komunikasi : komunikasi
# 715 : perbedaan : beda
# 716 : manakah : mana
# 717 : ny : ny
# 718 : had : had
# 719 : so : so
# 720 : kena : kena
# 721 : perhatikan : perhati
# 722 : dn : dn
# 723 : sambungkan : sambung
# 724 : meluncur : luncur
# 725 : pookok : pookok
# 726 : koneksinya : koneksi
# 727 : sangan : sangan
# 728 : prrtahankan : prrtahankan
# 729 : tersambung : sambung
# 730 : mantaaappp : mantaaappp
# 731 : 100 : 100
# 732 : pemerintah : perintah
# 733 : indonesia : indonesia
# 734 : obat : obat
# 735 : gvn : gvn
# 736 : pilihan : pilih
# 737 : bermanfaat : manfaat
# 738 : horang : horang
# 739 : marger : marger
# 740 : menyepi : nyepi
# 741 : kesendirian : sendiri
# 742 : smentara : smentara
# 743 : mbyak : mbyak
# 744 : tekan : tekan
# 745 : terhubung : hubung
# 746 : memperkuat : kuat
# 747 : sankat : sankat
# 748 : android : android
# 749 : mn : mn
# 750 : kpn : kpn
# 751 : bae : bae
# 752 : glk : glk
# 753 : nk : nk
# 754 : mntk : mntk
# 755 : smo : smo
# 756 : siapo : siapo
# 757 : yo : yo
# 758 : km : km
# 759 : jdi : jdi
# 760 : proses : proses
# 761 : daftarkan : daftar
# 762 : akun : akun
# 763 : berbayarnya : bayar
# 764 : kunrangi : kunrangi
# 765 : yah : yah
# 766 : gratisannya : gratis
# 767 : meskipung : meskipung
# 768 : penjuru : penjuru
# 769 : jepang : jepang
# 770 : asia : asia
# 771 : job : job
# 772 : vpnya : vpnya
# 773 : disaat : saat
# 774 : gunung : gunung
# 775 : trima : trima
# 776 : kembalikan : kembali
# 777 : baiknya : baik
# 778 : mengjasilkan : mengjasilkan
# 779 : penghasilan : hasil
# 780 : secure : secure
# 781 : maju : maju
# 782 : dihilangkan : hilang
# 783 : bnget : bnget
# 784 : diblok : blok
# 785 : diaktifkan : aktif
# 786 : didaerah : daerah
# 787 : turun : turun
# 788 : ku : ku
# 789 : jang : jang
# 790 : gituu : gituu
# 791 : tiba² : tiba
# 792 : sebenar : benar
# 793 : batasi : batas
# 794 : balance : balance
# 795 : keluarkan : keluar
# 796 : sejujurnya : jujur
# 797 : tercepat : cepat
# 798 : kupake : kupake
# 799 : memiliki : milik
# 800 : pembayaran : bayar
# 801 : berlangan : lang
# 802 : tanggal : tanggal
# 803 : 8 : 8
# 804 : nama : nama
# 805 : sur : sur
# 806 : ka : ka
# 807 : 0812 : 0812
# 808 : 5835 : 5835
# 809 : mengerti : erti
# 810 : potong : potong
# 811 : uangnya : uang
# 812 : mala : mala
# 813 : lalod : lalod
# 814 : sistemnya : sistem
# 815 : bertahun2 : bertahun2
# 816 : kualitasnya : kualitas
# 817 : pih : pih
# 818 : pedalaman : dalam
# 819 : joss : joss
# 820 : jangka : jangka
# 821 : tangkapan : tangkap
# 822 : kuat : kuat
# 823 : hilang2 : hilang2
# 824 : menjengkel : jengkel
# 825 : xnxx : xnxx
# 826 : setuju : tuju
# 827 : tertera : tera
# 828 : layar : layar
# 829 : af : af
# 830 : ranting : ranting
# 831 : block : block
# 832 : diblokir : blokir
# 833 : dibuka : buka
# 834 : pokok : pokok
# 835 : diluar : luar
# 836 : nalar : nalar
# 837 : dipakai : pakai
# 838 : bentar : bentar
# 839 : kilat : kilat
# 840 : jujurr : jujurr
# 841 : bertahun : tahun
# 842 : devloper : devloper
# 843 : terputusnya : putus
# 844 : keneksi : keneksi
# 845 : teman² : teman
# 846 : pokoke : pokoke
# 847 : goood : goood
# 848 : tensi : tensi
# 849 : tp : tp
# 850 : tlong : tlong
# 851 : asyik : asyik
# 852 : tolongdong : tolongdong
# 853 : downloadnya : downloadnya
# 854 : tu : tu
# 855 : bangat : bangat
# 856 : trimah : trimah
# 857 : lucu : lucu
# 858 : mendukung : dukung
# 859 : operasional : operasional
# 860 : digoogle : digoogle
# 861 : berfungsi : fungsi
# 862 : iniya : iniya
# 863 : dengn : dengn
# 864 : mmbantu : mmbantu
# 865 : gamdos : gamdos
# 866 : apik : apik
# 867 : kembangkan : kembang
# 868 : fitur2 : fitur2
# 869 : terbaru : baru
# 870 : terkunci : kunci
# 871 : n : n
# 872 : ragu : ragu
# 873 : hambatan : hambat
# 874 : meng : meng
# 875 : bobrok : bobrok
# 876 : kepake : kepake
# 877 : 400mb : 400mb
# 878 : down : down
# 879 : bermutu : mutu
# 880 : gerangan : gerangan
# 881 : tambahkan : tambah
# 882 : bintangnya : bintang
# 883 : over : over
# 884 : all : all
# 885 : klau : klau
# 886 : ads : ads
# 887 : bang : bang
# 888 : jaya : jaya
# 889 : kesel : kesel
# 890 : bulannya : bulan
# 891 : diskon : diskon
# 892 : 50 : 50
# 893 : beda : beda
# 894 : bug : bug
# 895 : segudang : gudang
# 896 : bosok : bosok
# 897 : connectnya : connectnya
# 898 : langgeng : langgeng
# 899 : miami : miami
# 900 : amerika : amerika
# 901 : serikat : serikat
# 902 : kedalam : dalam
# 903 : meningkatkan : tingkat
# 904 : on : on
# 905 : kemarin : kemarin
# 906 : perbarui : baru
# 907 : beredar : edar
# 908 : kabar : kabar
# 909 : peraturan : atur
# 910 : negri : negri
# 911 : arab : arab
# 912 : kah : kah
# 913 : bnar : bnar
# 914 : mempercepat : cepat
# 915 : harap : harap
# 916 : dikembangkan : kembang
# 917 : laqi : laqi
# 918 : masi : mas
# 919 : and : and
# 920 : kulaitas : kulaitas
# 921 : membayar : bayar
# 922 : mebuka : mebuka
# 923 : tq : tq
# 924 : kukasih : kasih
# 925 : rating : rating
# 926 : biarpun : biarpun
# 927 : kartu : kartu
# 928 : im3 : im3
# 929 : indosat : indosat
# 930 : wajar2 : wajar2
# 931 : gitu : gitu
# 932 : repot : repot
# 933 : dear : dear
# 934 : developer : developer
# 935 : innovative : innovative
# 936 : connecting : connecting
# 937 : proxy : proxy
# 938 : 10 : 10
# 939 : haiya : haiya
# 940 : modal : modal
# 941 : looo : looo
# 942 : berbqyar : berbqyar
# 943 : protes : protes
# 944 : rutin : rutin
# 945 : jarigan : jarigan
# 946 : berkomunikasi : komunikasi
# 947 : dipertahankan : tahan
# 948 : mohondi : mohondi
# 949 : loadingnya : loadingnya
# 950 : tingkatlan : tingkatlan
# 951 : y : y
# 952 : layanan : layan
# 953 : tutup : tutup
# 954 : nunggu : nunggu
# 955 : selesai : selesai
# 956 : dwonload : dwonload
# 957 : 7 : 7
# 958 : sadar : sadar
# 959 : play : play
# 960 : perpanjangan : panjang
# 961 : rp : rp
# 962 : 590 : 590
# 963 : dianggap : anggap
# 964 : ikln : ikln
# 965 : bnyk : bnyk
# 966 : dngan : dngan
# 967 : hasilnya : hasil
# 968 : sangag : sangag
# 969 : fiturnya : fiturnya
# 970 : penelusurannya : telusur
# 971 : wajib : wajib
# 972 : jangakauan : jangakauan
# 973 : konektivitasnya : konektivitasnya
# 974 : kekuatan : kuat
# 975 : signal : signal
# 976 : teratasi : atas
# 977 : karenakan : karena
# 978 : salah : salah
# 979 : mahal : mahal
# 980 : ad : ad
# 981 : tidk : tidk
# 982 : kalaw : kalaw
# 983 : kcepatan : kcepatan
# 984 : gg : gg
# 985 : cuy : cuy
# 986 : gabut : gabut
# 987 : nich : nich
# 988 : acara : acara
# 989 : loading2 : loading2
# 990 : zos : zos
# 991 : gandoz : gandoz
# 992 : nambahin : nambahin
# 993 : hmmm : hmmm
# 994 : tambahin : tambahin
# 995 : yaasmoga : yaasmoga
# 996 : gambarnya : gambar
# 997 : deep : deep
# 998 : melehoy : melehoy
# 999 : diperbaikin : diperbaikin
# 1000 : 𝐴𝑝𝑙𝑖𝑘𝑎𝑠𝑖𝑛𝑦𝑎 :
# 1001 : 𝑏𝑒𝑛𝑒𝑟2 : 2
# 1002 : 𝑏𝑎𝑔𝑢𝑠 :
# 1003 : 𝑑𝑎𝑛 :
# 1004 : 𝑡𝑖𝑑𝑎𝑘 :
# 1005 : 𝑚𝑒𝑛𝑔𝑒𝑐𝑒𝑤𝑎𝑘𝑎𝑛 :
# 1006 : 𝑗𝑗𝑎𝑑𝑖 :
# 1007 : 𝑠𝑎𝑦𝑎 :
# 1008 : 𝑘𝑎𝑠𝑖 :
# 1009 : 𝑏𝑖𝑛𝑡𝑎𝑛𝑔 :
# 1010 : wifi : wifi
# 1011 : mem : mem
# 1012 : apresiasi : apresiasi
# 1013 : terhubungnya : hubung
# 1014 : tunggu : tunggu
# 1015 : hehehe : hehehe
# 1016 : performa : performa
# 1017 : mengaktifkan : aktif
# 1018 : untuak : untuak
# 1019 : karingan : karingan
# 1020 : apkmya : apkmya
# 1021 : nih : nih
# 1022 : mantep : mantep
# 1023 : kekurangan : kurang
# 1024 : menjelajah : jelajah
# 1025 : pribadian : pribadi
# 1026 : menjangkau : jangkau
# 1027 : hanpone : hanpone
# 1028 : anjeng : anjeng
# 1029 : ayo : ayo
# 1030 : dowlod : dowlod
# 1031 : masuknya : masuk
# 1032 : didowlod : didowlod
# 1033 : penvet : penvet
# 1034 : menu : menu
# 1035 : bnr² : bnr
# 1036 : servernya : servernya
# 1037 : test : test
# 1038 : nggak : nggak
# 1039 : setel : setel
# 1040 : 40 : 40
# 1041 : kb : kb
# 1042 : s : s
# 1043 : mb : mb
# 1044 : useless : useless
# 1045 : kelancarannya : lancar
# 1046 : min : min
# 1047 : nonaktifkan : nonaktif
# 1048 : penarikan : tari
# 1049 : ditarik : tarik
# 1050 : persetujuan : tuju
# 1051 : ssya : ssya
# 1052 : walapun : walapun
# 1053 : berbahaya : bahaya
# 1054 : metode : metode
# 1055 : percobaan : coba
# 1056 : tdk : tdk
# 1057 : membatalkan : batal
# 1058 : langganan : langgan
# 1059 : kehilangan : hilang
# 1060 : 187rb : 187rb
# 1061 : trnyata : trnyata
# 1062 : pmbayaran : pmbayaran
# 1063 : menghargai : harga
# 1064 : pertahankan : tahan
# 1065 : perbanyak : banyak
# 1066 : dipake : dipake
# 1067 : ilang : ilang
# 1068 : doang : doang
# 1069 : dibanyakin : dibanyakin
# 1070 : menghemat : hemat
# 1071 : kecuali : kecuali
# 1072 : paket : paket
# 1073 : s8nyal : s8nyal
# 1074 : mengisi : isi
# 1075 : artikel : artikel
# 1076 : deh : deh
# 1077 : aksesnya : akses
# 1078 : cepet : cepet
# 1079 : maya : maya
# 1080 : medukung : medukung
# 1081 : kelinci : kelinci
# 1082 : wilayah : wilayah
# 1083 : terpercaya : percaya
# 1084 : pemakaian : pakai
# 1085 : ko : ko
# 1086 : pemberitahuan : pemberitahuan
# 1087 : kedepanya : depa
# 1088 : cookk : cookk
# 1089 : bangke : bangke
# 1090 : sndiri : sndiri
# 1091 : hadeehhhhh : hadeehhhhh
# 1092 : lama2 : lama2
# 1093 : emosi : emosi
# 1094 : cokkk : cokkk
# 1095 : mudahan : mudah
# 1096 : speednya : speednya
# 1097 : anjeengg : anjeengg
# 1098 : tombol : tombol
# 1099 : duit : duit
# 1100 : njeeengg : njeeengg
# 1101 : call : call
# 1102 : gaada : gaada
# 1103 : gangguan : ganggu
# 1104 : sengaja : sengaja
# 1105 : dibikin : bikin
# 1106 : engga : engga
# 1107 : gausah : gausah
# 1108 : berkualitas : kualitas
# 1109 : urusan : urus
# 1110 : lamban : lamban
# 1111 : tindak : tindak
# 1112 : program : program
# 1113 : complit : complit
# 1114 : dicari : cari
# 1115 : prabayar : prabayar
# 1116 : menerima : terima
# 1117 : pertahan : tahan
# 1118 : yaaa : yaaa
# 1119 : pelayan : layan
# 1120 : gouddd : gouddd
# 1121 : user : user
# 1122 : mengeluh : keluh
# 1123 : kusaranin : kusaranin
# 1124 : lu : lu
# 1125 : notifikasi : notifikasi
# 1126 : mengambang : ambang
# 1127 : close : close
# 1128 : paksa : paksa
# 1129 : berhenti : henti
# 1130 : serius : serius
# 1131 : nanya : nanya
# 1132 : review : review
# 1133 : gmn : gmn
# 1134 : emg : emg
# 1135 : trial : trial
# 1136 : lancaaaaar : lancaaaaar
# 1137 : btw : btw
# 1138 : netflix : netflix
# 1139 : knp : knp
# 1140 : turbovpn : turbovpn
# 1141 : konek : konek
# 1142 : korea : korea
# 1143 : eh : eh
# 1144 : mexico : mexico
# 1145 : singapore : singapore
# 1146 : aussie : aussie
# 1147 : netflixnya : netflixnya
# 1148 : negaranya : negara
# 1149 : sad : sad
# 1150 : mengalami : alami
# 1151 : area : area
# 1152 : menghubungkan : hubung
# 1153 : minimal : minimal
# 1154 : 100kb : 100kb
# 1155 : terkoneksi : koneksi
# 1156 : alami : alami
# 1157 : _ :
# 1158 : not : not
# 1159 : bad : bad
# 1160 : easy : easy
# 1161 : to : to
# 1162 : use : use
# 1163 : ui : ui
# 1164 : protokolnya : protokol
# 1165 : hilangkan : hilang
# 1166 : pdhal : pdhal
# 1167 : tipe : tipe
# 1168 : meningkat : tingkat
# 1169 : skip : skip
# 1170 : berulang2 : berulang2
# 1171 : harga : harga
# 1172 : rupa : rupa
# 1173 : k : k
# 1174 : cuan : cuan
# 1175 : dihasilkan : hasil
# 1176 : mengembangkan : kembang
# 1177 : kelebihan : lebih
# 1178 : operasikan : operasi
# 1179 : zona : zona
# 1180 : berkat : berkat
# 1181 : pekerjaan : kerja
# 1182 : latar : latar
# 1183 : apalah : apa
# 1184 : mempengaruhi : pengaruh
# 1185 : penilaian : nilai
# 1186 : 30 : 30
# 1187 : habis : habis
# 1188 : naikin : naikin
# 1189 : knapa : knapa
# 1190 : sampe : sampe
# 1191 : 4mb : 4mb
# 1192 : 500kb : 500kb
# 1193 : admin : admin
# 1194 : dibeneri : dibeneri
# 1195 : menyambungkan : sambung
# 1196 : ulang : ulang
# 1197 : manual : manual
# 1198 : berinovasi : inovasi
# 1199 : contohnya : contoh
# 1200 : terwujud : wujud
# 1201 : harapkan : harap
# 1202 : setau : tau
# 1203 : menambah : tambah
# 1204 : melemah : lemah
# 1205 : online : online
# 1206 : 100k : 100k
# 1207 : 0 : 0
# 1208 : 00k : 00k
# 1209 : b : b
# 1210 : solusi : solusi
# 1211 : nyah : nyah
# 1212 : buatannya : buat
# 1213 : frustasi : frustasi
# 1214 : jelekin : jelekin
# 1215 : ungkapkan : ungkap
# 1216 : fakta : fakta
# 1217 : ngeselin : ngeselin
# 1218 : isinya : isi
# 1219 : pemakaiannya : pakai
# 1220 : pemakai : pakai
# 1221 : setahun : tahun
# 1222 : gratisnya : gratis
# 1223 : digital : digital
# 1224 : pakenya : pakenya
# 1225 : jarang : jarang
# 1226 : ngambil : ngambil
# 1227 : dipermasalahkan : masalah
# 1228 : tambahan : tambah
# 1229 : aspirasiku : aspirasi
# 1230 : dengar : dengar
# 1231 : nambah : nambah
# 1232 : perubahan : ubah
# 1233 : sambungan : sambung
# 1234 : nempel : nempel
# 1235 : beruntun : untun
# 1236 : masak : masak
# 1237 : alhasil : alhasil
# 1238 : connentnya : connentnya
# 1239 : kelebihannya : lebih
# 1240 : bermasalah : masalah
# 1241 : kekurangnnya : kekurangnnya
# 1242 : youtube : youtube
# 1243 : putar : putar
# 1244 : kebelakang : belakang
# 1245 : pesawat : pesawat
# 1246 : mematikannya : mati
# 1247 : youtubenya : youtubenya
# 1248 : terbantu : bantu
# 1249 : perpanjang : panjang
# 1250 : lola : lola
# 1251 : telpon : telpon
# 1252 : janji : janji
# 1253 : andalkan : andal
# 1254 : pergi : pergi
# 1255 : melaut : laut
# 1256 : terjangkau : jangkau
# 1257 : batalkan : batal
# 1258 : knpa : knpa
# 1259 : skrang : skrang
# 1260 : mantuuuap : mantuuuap
# 1261 : broo : broo
# 1262 : maklum : maklum
# 1263 : wkwk : wkwk
# 1264 : uinstal : uinstal
# 1265 : mnh : mnh
# 1266 : pakainya : pakai
# 1267 : bngt : bngt
# 1268 : apn : apn
# 1269 : diragukan : ragu
# 1270 : konektifitas : konektifitas
# 1271 : kegunaannya : guna
# 1272 : rekomendasikan : rekomendasi
# 1273 : memakainya : maka
# 1274 : abal2 : abal2
# 1275 : dipercaya : percaya
# 1276 : buffering : buffering
# 1277 : memadai : pada
# 1278 : menggunakannya : guna
# 1279 : kapok : kapok
# 1280 : ngak : ngak
# 1281 : dañ : da
# 1282 : kekurangannya : kurang
# 1283 : menggangu : menggangu
# 1284 : sedit : sedit
# 1285 : masalanya : masala
# 1286 : kebagusanny : kebagusanny
# 1287 : mendownload : mendownload
# 1288 : takut : takut
# 1289 : berkembang : kembang
# 1290 : klou : klou
# 1291 : mudanan : mudanan
# 1292 : menyusul : susul
# 1293 : leletnya : lelet
# 1294 : apun : apun
# 1295 : durasinya : durasi
# 1296 : mah : mah
# 1297 : parahnya : parah
# 1298 : berimbang : imbang
# 1299 : kecewanya : kecewa
# 1300 : uninstal : uninstal
# 1301 : padam : padam
# 1302 : menyalakan : nyala
# 1303 : hubungkan : hubung
# 1304 : facebook : facebook
# 1305 : normal : normal
# 1306 : kuga : kuga
# 1307 : instalgram : instalgram
# 1308 : berharap : harap
# 1309 : mengkoneksinya : koneksi
# 1310 : gagal : gagal
# 1311 : berjam2 : berjam2
# 1312 : efek : efek
# 1313 : gede : gede
# 1314 : menghapus : hapus
# 1315 : deskripsi : deskripsi
# 1316 : dibatasi : batas
# 1317 : membatasi : batas
# 1318 : baiknyo : baiknyo
# 1319 : perkuat : kuat
# 1320 : bangst : bangst
# 1321 : jngn : jngn
# 1322 : von : von
# 1323 : kendalanya : kendala
# 1324 : tanda : tanda
# 1325 : silang : silang
# 1326 : ditungguin : ditungguin
# 1327 : kyk : kyk
# 1328 : trs : trs
# 1329 : kemahalan : mahal
# 1330 : privaci : privaci
# 1331 : login : login
# 1332 : slm : slm
# 1333 : dr : dr
# 1334 : dikit : dikit
# 1335 : dicoba : coba
# 1336 : beranda : beranda
# 1337 : bukanya : buka
# 1338 : pul : pul
# 1339 : sanggat : sanggat
# 1340 : ehmm : ehmm
# 1341 : puji : puji
# 1342 : lokal : lokal
# 1343 : sever : sever
# 1344 : keamanan : aman
# 1345 : terjamin : jamin
# 1346 : keamanannya : aman
# 1347 : or : or
# 1348 : in8 : in8
# 1349 : game2 : game2
# 1350 : jebol : jebol
# 1351 : hahahaaa : hahahaaa
# 1352 : jaman : jaman
# 1353 : candy : candy
# 1354 : kaboom : kaboom
# 1355 : ampe : ampe
# 1356 : now : now
# 1357 : wort : wort
# 1358 : it : it
# 1359 : voba : voba
# 1360 : logo : logo
# 1361 : pojok : pojok
# 1362 : lo : lo
# 1363 : pade : pade
# 1364 : iyalah : iya
# 1365 : hahahaaaaa : hahahaaaaa
# 1366 : melengkapi : lengkap
# 1367 : kedepan : depan
# 1368 : kelemahannya : lemah
# 1369 : 33detik : 33detik
# 1370 : berminat : minat
# 1371 : percepat : cepat
# 1372 : sinyalnya : sinyal
# 1373 : baeee : baeee
# 1374 : perbaiking : perbaiking
# 1375 : ngapa : ngapa
# 1376 : standar : standar
# 1377 : ba : ba
# 1378 : lbih : lbih
# 1379 : trus : trus
# 1380 : nyangkut : nyangkut
# 1381 : nyasar : nyasar
# 1382 : kekonek : kekonek
# 1383 : dikembangin : dikembangin
# 1384 : penggunaannya : guna
# 1385 : overall : overall
# 1386 : kunci : kunci
# 1387 : solusinya : solusi
# 1388 : loding : loding
# 1389 : diluaskan : luas
# 1390 : ngga : ngga
# 1391 : mengkoneksikan : koneksi
# 1392 : splikasi : splikasi
# 1393 : dimengerti : erti
# 1394 : lokasinya : lokasi
# 1395 : gertis : gertis
# 1396 : anak : anak
# 1397 : bersemangat : semangat
# 1398 : jantan : jantan
# 1399 : suaranya : suara
# 1400 : cempreng : cempreng
# 1401 : tot : tot
# 1402 : gila : gila
# 1403 : sarang : sarang
# 1404 : dalem : dalem
# 1405 : otw : otw
# 1406 : ah : ah
# 1407 : youtobe : youtobe
# 1408 : okelah : oke
# 1409 : mempermudah : mudah
# 1410 : suport : suport
# 1411 : semenjak : semenjak
# 1412 : waw : waw
# 1413 : sangt2 : sangt2
# 1414 : pokonya : poko
# 1415 : downlod : downlod
# 1416 : pendek : pendek
# 1417 : watermark : watermark
# 1418 : diganti : ganti
# 1419 : bl : bl
# 1420 : tampil : tampil
# 1421 : diatas : atas
# 1422 : malu : malu
# 1423 : cuyyy : cuyyy
# 1424 : ditingkatin : ditingkatin
# 1425 : kdang2 : kdang2
# 1426 : kluar : kluar
# 1427 : ampun : ampun
# 1428 : mencegah : cegah
# 1429 : my : my
# 1430 : canggih : canggih
# 1431 : akurat : akurat
# 1432 : menesel : menesel
# 1433 : masang : masang
# 1434 : lh : lh
# 1435 : tingkat : tingkat
# 1436 : umtuk : umtuk
# 1437 : tampilah : tampi
# 1438 : pahami : paham
# 1439 : menunya : menu
# 1440 : maain : maain
# 1441 : khusus : khusus
# 1442 : of : of
# 1443 : duty : duty
# 1444 : delay : delay
# 1445 : nembak : nembak
# 1446 : terimah : terimah
# 1447 : store : store
# 1448 : tiada : tiada
# 1449 : nge : nge
# 1450 : like : like
# {'berguna': 'guna', 'masuk': 'masuk', 'situs': 'situs', 'susah': 'susah', 'akses': 'akses', 'suka': 'suka', 'error': 'error', 'iklan': 'iklan', 'nya': 'nya', 'gak': 'gak', 'banget': 'banget', 'kali': 'kali', 'main': 'main', 'cuman': 'cuman', '2': '2', '3': '3', 'muncul': 'muncul', 'durasi': 'durasi', 'iklannya': 'iklan', 'kerasa': 'rasa', 'wajar': 'wajar', 'intinya': 'inti', 'tuh': 'tuh', 'aplikasi': 'aplikasi', 'bagus': 'bagus', 'o': 'o', 'ω': '', 'apk': 'apk', 'sampah': 'sampah', 'jaringannya': 'jaring', 'lemot': 'lot', 'dimana': 'mana', 'iya': 'iya', 'dimaklumi': 'maklum', 'yoo': 'yoo', 'astaghh': 'astaghh', 'nonton': 'nonton', 'live': 'live', 'streaming': 'streaming', 'aja': 'aja', 'kualitas': 'kualitas', 'mentok': 'mentok', '240p': '240p', 'itupun': 'itu', 'kebanyakan': 'banyak', 'mutar': 'mutar', '144p': '144p', 'loading': 'loading', 'dibandingkan': 'banding', 'vpn': 'vpn', 'yg': 'yg', 'wow': 'wow', 'pake': 'pake', 'tembus': 'tembus', '1080p': '1080p', 'lancar': 'lancar', 'jaringan': 'jaring', 'nyesel': 'nyesel', 'download': 'download', 'rekomendasi': 'rekomendasi', 'hilang': 'hilang', 'status': 'status', 'bar': 'bar', 'ya': 'ya', 'tulisannya': 'tulis', 'enak': 'enak', 'kesalahan': 'salah', 'perangkat': 'perangkat', 'ketuk': 'ketuk', 'menyambung': 'sambung', 'disuruh': 'suruh', 'nyambung': 'nyambung', 'matikan': 'mati', 'lihat': 'lihat', 'suruh': 'suruh', 'rajin': 'rajin', 'keuntungan': 'untung', 'pembikinnya': 'bikin', 'bintang5pasti': 'bintang5pasti', 'turbo': 'turbo', 'memuaskan': 'muas', 'recommended': 'recommended', 'kalian2': 'kalian2', 'butuh': 'butuh', 'best': 'best', 'skrg': 'skrg', 'msh': 'msh', 'terbaik': 'baik', 'mudah': 'mudah', 'ga': 'ga', 'sulit': 'sulit', 'jaga': 'jaga', 'tingkatkan': 'tingkat', 'pengalaman': 'alam', 'skrng': 'skrng', 'coba': 'coba', 'buktikan': 'bukti', 'bedakan': 'beda', 'dngn': 'dngn', 'putus2': 'putus2', '20': '20', 'menit': 'menit', 'jalan': 'jalan', 'tiba2': 'tiba2', 'ganti': 'ganti', 'lokasi': 'lokasi', 'perbaiki': 'baik', 'kasih': 'kasih', '1': '1', 'bintang': 'bintang', '5': '5', 'maff': 'maff', 'buang': 'buang', 'delete': 'delete', 'karna': 'karna', 'sanga': 'sanga', 'kesal': 'kesal', 'koneksi': 'koneksi', 'non': 'non', 'aktif': 'aktif', 'kayak': 'kayak', 'gini': 'gin', 'sih': 'sih', 'tpi': 'tpi', 'msi': 'msi', 'agret': 'agret', 'sya': 'sya', 'brikn': 'brikn', '4': '4', 'bntng': 'bntng', 'dlu': 'dlu', 'lgi': 'lgi', 'diperbaiki': 'baik', 'sprti': 'sprti', 'terputus': 'putus', 'msih': 'msih', 'lambat': 'lambat', 'trllu': 'trllu', 'membantu': 'bantu', 'membuka': 'buka', 'link': 'link', 'd': 'd', 'blok': 'blok', 'sukses': 'sukses', 'gbsa': 'gbsa', 'kurangin': 'rangin', 'nnti': 'nnti', 'klo': 'klo', 'bsa': 'bsa', 'lg': 'lg', 'tmbh': 'tmbh', 'bntangnya': 'bntangnya', 'trims': 'trims', 'cocok': 'cocok', 'game': 'game', 'tolong': 'tolong', 'kadang': 'kadang', 'putus': 'putus', 'sendri': 'sendri', 'mohon': 'mohon', 'terimakasih': 'terimakasih', 'berkomentar': 'komentar', 'mts': 'mts', '2015': '2015', 'an': 'an', 'pakai': 'pakai', 'bagiku': 'bagi', 'keren': 'keren', 'pengin': 'pengin', 'luas': 'luas', 'premium': 'premium', 'berlangganan': 'langgan', 'memilih': 'pilih', 'uji': 'uji', 'pokoknya': 'pokok', 'makasih': 'makasih', 'cepat': 'cepat', 'ribet': 'ribet', 'namanya': 'nama', 'gratis': 'gratis', 'bayar': 'bayar', 'aplikasinya': 'aplikasi', 'boss': 'boss', 'menyenangkan': 'senang', 'web': 'web', 'jangkau': 'jangkau', 'memakai': 'pakai', 'kuharap': 'harap', 'perkembangan': 'kembang', 'update': 'update', 'memudahkan': 'mudah', 'semangat': 'semangat', 'kawan': 'kawan', 'kerja': 'kerja', 'asa': 'asa', 'hati': 'hati', 'disebabkan': 'sebab', 'mulut': 'mulut', 'tdak': 'tdak', 'dngar': 'dngar', 'orng²': 'orng', 'kenal': 'kenal', 'dri': 'dri', 'lingkungan': 'lingkung', 'nilai': 'nilai', 'mna': 'mna', 'mulutnya': 'mulut', 'otomatis': 'otomatis', 'pilih': 'pilih', 'peramban': 'ramban', 'full': 'full', 'maksimal': 'maksimal', 'jam': 'jam', 'segi': 'segi', 'lancarnya': 'lancar', 'kenceng': 'kenceng' ...
#                                                content  score    label  \
# 0    sangat berguna buat masuk ke situs yang susah ...      5  Positif
# 1    apk sampah jaringannya lemot terus iklan diman...      1  Negatif
# 2    kenapa dia gak hilang dari status bar ya mana ...      1  Negatif
# 3    bintang5pasti dong selama saya menggunakan vpn...      5  Positif
# 4    masalah nya suka putus2 sendiri vpn nya 20 men...      1  Negatif
# ..                                                 ...    ...      ...
# 495                    lancar jaya sedikit iklan wajar      5  Positif
# 496  aplikasi nya sangat bermanfaat dan bagus saat ...      5  Positif
# 497                            bagus tp iklannya bnyak      4  Positif
# 498              bagus nih jaringan nya tiada nge like      5  Positif
# 499          mudah dipakai dan sangat membantu sekali       5  Positif
#
#                                             content_sw  \
# 0    berguna masuk situs susah akses suka error ikl...
# 1    apk sampah jaringannya lemot iklan dimana iya ...
# 2    gak hilang status bar ya tulisannya gak enak k...
# 3    bintang5pasti vpn turbo memuaskan recommended ...
# 4    nya suka putus2 vpn nya 20 menit jalan bagus t...
# ..                                                 ...
# 495                            lancar jaya iklan wajar
# 496  aplikasi nya bermanfaat bagus bermain game apl...
# 497                            bagus tp iklannya bnyak
# 498              bagus nih jaringan nya tiada nge like
# 499                             mudah dipakai membantu
#
#                                          content_token  \
# 0    [berguna, masuk, situs, susah, akses, suka, er...
# 1    [apk, sampah, jaringannya, lemot, iklan, diman...
# 2    [gak, hilang, status, bar, ya, tulisannya, gak...
# 3    [bintang5pasti, vpn, turbo, memuaskan, recomme...
# 4    [nya, suka, putus2, vpn, nya, 20, menit, jalan...
# ..                                                 ...
# 495                       [lancar, jaya, iklan, wajar]
# 496  [aplikasi, nya, bermanfaat, bagus, bermain, ga...
# 497                       [bagus, tp, iklannya, bnyak]
# 498      [bagus, nih, jaringan, nya, tiada, nge, like]
# 499                         [mudah, dipakai, membantu]
#
#                                           content_stem
# 0    guna masuk situs susah akses suka error iklan ...
# 1    apk sampah jaring lot iklan mana iya maklum ik...
# 2    gak hilang status bar ya tulis gak enak salah ...
# 3    bintang5pasti vpn turbo muas recommended bange...
# 4    nya suka putus2 vpn nya 20 menit jalan bagus t...
# ..                                                 ...
# 495                            lancar jaya iklan wajar
# 496  aplikasi nya manfaat bagus main game aplikasi ...
# 497                               bagus tp iklan bnyak
# 498                bagus nih jaring nya tiada nge like
# 499                                  mudah pakai bantu
#
# [477 rows x 6 columns]

# %%
# Save data stemmed to csv
data.to_csv('text_hasil_stemming.csv', index=False)

# Load the data again
df = pd.read_csv('text_hasil_stemming.csv')

# %%
# Import sklearn for doing naive bayes analysis
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# %%
# Performing Naive bayes
nb = GaussianNB()

tfidf = TfidfVectorizer()
tfidf_X = tfidf.fit_transform(df['content_stem'])

# %%
X = tfidf_X.toarray()
y = df['label']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                   test_size=0.33,
                                                   random_state=42)

# %%
# Performing Naive Bayes
nb.fit(X_train, y_train)

# Predicting y_test
predicted = nb.predict(X_test)

# %%
# Creating df for comparing predicted value and y_test 
comparison = pd.DataFrame({'initial_label':y_test, 'predicted_label':predicted})

# Visualizing the label
sns.countplot(data=comparison, x='initial_label')
plt.title('Label Berdasarkan Skor')
plt.ylabel('Frekuensi')
plt.savefig('label-berdasarkan-skor.png')

# %%
# Visualizing based on the NB
sns.countplot(data=comparison, x='predicted_label')
plt.title('Labeling Berdasarkan Naive Bayes')
plt.ylabel('Frekuensi')
plt.savefig('label-berdasarkan-naive-bayes.png')

# %%
# Calculating Accuracy
accuracy = accuracy_score(y_test, predicted)
f1_score = f1_score(y_test, predicted, pos_label='Negatif')
recall = recall_score(y_test, predicted, pos_label='Negatif')
precision = precision_score(y_test, predicted, pos_label='Negatif')
class_report = classification_report(y_test, predicted)
con_matrix = confusion_matrix(y_test, predicted)

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /home/septian/anaconda3/lib/python3.11/site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /home/septian/anaconda3/lib/python3.11/site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /home/septian/anaconda3/lib/python3.11/site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in /home/septian/anaconda3/lib/python3.11/site-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/septian/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/septian/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/septian/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/septian/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/septian/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/septian/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/septian/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/septian/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# Visualizing the text
from wordcloud import WordCloud, STOPWORDS

content = ' '.join(review for review in df['content_stem'])

wordcloud = WordCloud(max_font_size=50,
                     max_words=100,
                     background_color='white',
                     colormap='Accent', 
                     stopwords=STOPWORDS).generate(content)
plt.imshow(wordcloud, interpolation='bilinear')
plt.figure(figsize=(14,8))
plt.axis('off')
plt.savefig('wordcloud.png')

# %%
print('Accuracy dari model adalah:', accuracy)
print('Skor Presisi dari model adalah:', precision)
print('___________________________________')
print('Confusion matrix:\n',con_matrix)
print('Classification Report:\n', class_report)
# Out:
# Accuracy dari model adalah: 0.689873417721519
# Skor Presisi dari model adalah: 0.23636363636363636
# ___________________________________
# Confusion matrix:
#  [[13  7]
#  [42 96]]
# Classification Report:
#                precision    recall  f1-score   support
#
#      Negatif       0.24      0.65      0.35        20
#      Positif       0.93      0.70      0.80       138
#
#     accuracy                           0.69       158
#    macro avg       0.58      0.67      0.57       158
# weighted avg       0.84      0.69      0.74       158

# %%
class_report
# Out:
# '              precision    recall  f1-score   support\n\n     Negatif       0.24      0.65      0.35        20\n     Positif       0.93      0.70      0.80       138\n\n    accuracy                           0.69       158\n   macro avg       0.58      0.67      0.57       158\nweighted avg       0.84      0.69      0.74       158\n'
